# %% [markdown]
# Importing all necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Importing the dataset with the help of pandas library

# %%
df = pd.read_csv(r"C:\Users\hp\Downloads\Walmart (1).csv")

# %%
df
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# 0     211.096358         8.106
# 1     211.242170         8.106
# 2     211.289143         8.106
# 3     211.319643         8.106
# 4     211.350143         8.106
# ...          ...           ...
# 6430  192.013558         8.684
# 6431  192.170412         8.667
# 6432  192.327265         8.667
# 6433  192.330854         8.667
# 6434  192.308899         8.667
#
# [6435 rows x 8 columns]

# %% [markdown]
# Using head function to view the top five rows

# %%
df.head()
# Out:
#    Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1  05-02-2010    1643690.90             0        42.31       2.572
# 1      1  12-02-2010    1641957.44             1        38.51       2.548
# 2      1  19-02-2010    1611968.17             0        39.93       2.514
# 3      1  26-02-2010    1409727.59             0        46.63       2.561
# 4      1  05-03-2010    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment
# 0  211.096358         8.106
# 1  211.242170         8.106
# 2  211.289143         8.106
# 3  211.319643         8.106
# 4  211.350143         8.106

# %%
df.columns
# Out:
# Index(['Store', 'Date', 'Weekly_Sales', 'Holiday_Flag', 'Temperature',
#        'Fuel_Price', 'CPI', 'Unemployment'],
#       dtype='object')

# %%
df.shape
# Out:
# (6435, 8)

# %%
df
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# 0     211.096358         8.106
# 1     211.242170         8.106
# 2     211.289143         8.106
# 3     211.319643         8.106
# 4     211.350143         8.106
# ...          ...           ...
# 6430  192.013558         8.684
# 6431  192.170412         8.667
# 6432  192.327265         8.667
# 6433  192.330854         8.667
# 6434  192.308899         8.667
#
# [6435 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   object
#  2   Weekly_Sales  6435 non-null   float64
#  3   Holiday_Flag  6435 non-null   int64
#  4   Temperature   6435 non-null   float64
#  5   Fuel_Price    6435 non-null   float64
#  6   CPI           6435 non-null   float64
#  7   Unemployment  6435 non-null   float64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 402.3+ KB

# %% [markdown]
# To find the null value in the dataset

# %%
df.isnull().sum()
# Out:
# Store           0
# Date            0
# Weekly_Sales    0
# Holiday_Flag    0
# Temperature     0
# Fuel_Price      0
# CPI             0
# Unemployment    0
# dtype: int64

# %% [markdown]
# Insight
#
#
# There is no null value in the dataset

# %%
df.index
# Out:
# RangeIndex(start=0, stop=6435, step=1)

# %% [markdown]
# Using Tail function to view the bottom 5 row of the dataset

# %%
df.tail()
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# 6430  192.013558         8.684
# 6431  192.170412         8.667
# 6432  192.327265         8.667
# 6433  192.330854         8.667
# 6434  192.308899         8.667

# %%
df.dtypes
# Out:
# Store             int64
# Date             object
# Weekly_Sales    float64
# Holiday_Flag      int64
# Temperature     float64
# Fuel_Price      float64
# CPI             float64
# Unemployment    float64
# dtype: object

# %% [markdown]
# To find the mean,std,25%,50%,75%,max,min of the datset

# %%
df.describe()
# Out:
#              Store  Weekly_Sales  Holiday_Flag  Temperature   Fuel_Price  \
# count  6435.000000  6.435000e+03   6435.000000  6435.000000  6435.000000
# mean     23.000000  1.046965e+06      0.069930    60.663782     3.358607
# std      12.988182  5.643666e+05      0.255049    18.444933     0.459020
# min       1.000000  2.099862e+05      0.000000    -2.060000     2.472000
# 25%      12.000000  5.533501e+05      0.000000    47.460000     2.933000
# 50%      23.000000  9.607460e+05      0.000000    62.670000     3.445000
# 75%      34.000000  1.420159e+06      0.000000    74.940000     3.735000
# max      45.000000  3.818686e+06      1.000000   100.140000     4.468000
#
#                CPI  Unemployment
# count  6435.000000   6435.000000
# mean    171.578394      7.999151
# std      39.356712      1.875885
# min     126.064000      3.879000
# 25%     131.735000      6.891000
# 50%     182.616521      7.874000
# 75%     212.743293      8.622000
# max     227.232807     14.313000

# %% [markdown]
# Plotting the boxplot to find the Outliers in the dataset

# %%
df.boxplot(["Store"])
# Out:
# <AxesSubplot:>

# %%
df.boxplot(["Weekly_Sales"])
# Out:
# <AxesSubplot:>

# %%
df.boxplot(["Unemployment"])
# Out:
# <AxesSubplot:>

# %%
df.boxplot(["Temperature"])
# Out:
# <AxesSubplot:>

# %%
df.boxplot(["Fuel_Price"])
# Out:
# <AxesSubplot:>

# %%
df.boxplot(["CPI"])
# Out:
# <AxesSubplot:>

# %%
df.boxplot(["Holiday_Flag"])
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,10))
count=1
plt.subplot(2,4,count)
sns.boxplot(df.Store)
count=count+1
plt.subplot(2,4,count)
sns.boxplot(df.Weekly_Sales)
count=count+1
plt.subplot(2,4,count)
sns.boxplot(df.Holiday_Flag)
count=count+1
plt.subplot(2,4,count)
sns.boxplot(df.Temperature)
count=count+1
plt.subplot(2,4,count)
sns.boxplot(df.Fuel_Price)
count=count+1
plt.subplot(2,4,count)
sns.boxplot(df.CPI)
count=count+1
plt.subplot(2,4,count)
sns.boxplot(df.Unemployment)
plt.show()

# %% [markdown]
# Insights
#
# found the Outliers in Unemployment,Weekly_Sales columns only.

# %%
 df.columns
# Out:
# Index(['Store', 'Date', 'Weekly_Sales', 'Holiday_Flag', 'Temperature',
#        'Fuel_Price', 'CPI', 'Unemployment'],
#       dtype='object')

# %%
def remove_outliers(df,columnName):
    q1= np.percentile(df[columnName],0.25)
    q3= np.percentile(df[columnName],0.75)
    iqr = q3 - q1
    ul =q3 + 1.5*q3
    ll =q1 - 1.5*q1
    df= df[(df[columnName] > ll) & (df[columnName] < ul)]
    return df

# %%
df = remove_outliers(df,"Weekly_Sales")

# %%
sns.boxplot(df['Weekly_Sales'])
# Out:
# <AxesSubplot:xlabel='Weekly_Sales'>

# %%
df = remove_outliers(df,"Unemployment")

# %%
sns.boxplot(df['Unemployment'])
# Out:
# <AxesSubplot:xlabel='Unemployment'>

# %%
sns.heatmap(df.corr(),annot = True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df)

# %%
def extract_week(df):
  Date ='Date'
  df[Date]=pd.to_datetime(df[Date],infer_datetime_format=True)
  df['week'] = pd.DatetimeIndex(df[Date]).week
  df['month'] = pd.DatetimeIndex(df[Date]).month
  df['year'] = pd.DatetimeIndex(df[Date]).year

# %%
extract_week(df)

# %%
df.head()
# Out:
#      Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 286      3 2010-05-02     461622.22             0        45.71       2.572
# 287      3 2010-12-02     420728.96             1        47.93       2.548
# 288      3 2010-02-19     421642.19             0        47.07       2.514
# 289      3 2010-02-26     407204.86             0        52.05       2.561
# 290      3 2010-05-03     415202.04             0        53.04       2.625
#
#             CPI  Unemployment  week  month  year
# 286  214.424881         7.368    17      5  2010
# 287  214.574792         7.368    48     12  2010
# 288  214.619887         7.368     7      2  2010
# 289  214.647513         7.368     8      2  2010
# 290  214.675139         7.368    18      5  2010

# %%
df['year'].value_counts()
# Out:
# 2011    667
# 2010    589
# 2012    584
# Name: year, dtype: int64

# %%
df['month'].value_counts()
# Out:
# 4     184
# 10    173
# 9     171
# 5     169
# 7     166
# 3     158
# 8     151
# 2     145
# 1     145
# 6     140
# 12    128
# 11    110
# Name: month, dtype: int64

# %%
plt.figure(figsize=(10,10))
sns.barplot(data=df,x='month',y='Weekly_Sales',hue='year')
plt.title("Sales year wise")
plt.xlabel('month')
plt.ylabel('sales')
plt.show()

# %%
sns.scatterplot(data=df,x='month',y='Weekly_Sales',hue='Store')
# Out:
# <AxesSubplot:xlabel='month', ylabel='Weekly_Sales'>

# %%
sns.scatterplot(data=df,x='Fuel_Price',y='Weekly_Sales',hue='Store')
# Out:
# <AxesSubplot:xlabel='Fuel_Price', ylabel='Weekly_Sales'>

# %%
sns.scatterplot(data=df,x='Temperature',y='Weekly_Sales',hue='Store')
# Out:
# <AxesSubplot:xlabel='Temperature', ylabel='Weekly_Sales'>

# %%
sns.scatterplot(data=df,x='Unemployment',y='Weekly_Sales',hue='Store')
# Out:
# <AxesSubplot:xlabel='Unemployment', ylabel='Weekly_Sales'>

# %%
sns.scatterplot(data=df,x='CPI',y='Weekly_Sales',hue='Store')
# Out:
# <AxesSubplot:xlabel='CPI', ylabel='Weekly_Sales'>

# %%
sns.scatterplot(data=df,x='Store',y='Weekly_Sales',hue='Store')
# Out:
# <AxesSubplot:xlabel='Store', ylabel='Weekly_Sales'>

# %%
sns.scatterplot(data=df,y='Weekly_Sales',x='Temperature',hue='Holiday_Flag')
plt.title('Is sales depend on temp')
# Out:
# Text(0.5, 1.0, 'Is sales depend on temp')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1840 entries, 286 to 6291
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         1840 non-null   int64
#  1   Date          1840 non-null   datetime64[ns]
#  2   Weekly_Sales  1840 non-null   float64
#  3   Holiday_Flag  1840 non-null   int64
#  4   Temperature   1840 non-null   float64
#  5   Fuel_Price    1840 non-null   float64
#  6   CPI           1840 non-null   float64
#  7   Unemployment  1840 non-null   float64
#  8   week          1840 non-null   int64
#  9   month         1840 non-null   int64
#  10  year          1840 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(5)
# memory usage: 237.0 KB

# %%
df.head()
# Out:
#      Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 286      3 2010-05-02     461622.22             0        45.71       2.572
# 287      3 2010-12-02     420728.96             1        47.93       2.548
# 288      3 2010-02-19     421642.19             0        47.07       2.514
# 289      3 2010-02-26     407204.86             0        52.05       2.561
# 290      3 2010-05-03     415202.04             0        53.04       2.625
#
#             CPI  Unemployment  week  month  year
# 286  214.424881         7.368    17      5  2010
# 287  214.574792         7.368    48     12  2010
# 288  214.619887         7.368     7      2  2010
# 289  214.647513         7.368     8      2  2010
# 290  214.675139         7.368    18      5  2010

# %%
df.columns
# Out:
# Index(['Store', 'Date', 'Weekly_Sales', 'Holiday_Flag', 'Temperature',
#        'Fuel_Price', 'CPI', 'Unemployment', 'week', 'month', 'year'],
#       dtype='object')

# %%
x=df.loc[ :, ['Store','Holiday_Flag','Temperature','Fuel_Price','CPI','Unemployment','week','month','year']]
x
# Out:
#       Store  Holiday_Flag  Temperature  Fuel_Price         CPI  Unemployment  \
# 286       3             0        45.71       2.572  214.424881         7.368
# 287       3             1        47.93       2.548  214.574792         7.368
# 288       3             0        47.07       2.514  214.619887         7.368
# 289       3             0        52.05       2.561  214.647513         7.368
# 290       3             0        53.04       2.625  214.675139         7.368
# ...     ...           ...          ...         ...         ...           ...
# 6287     44             0        64.80       3.821  131.043000         5.407
# 6288     44             0        61.79       3.815  131.075667         5.217
# 6289     44             0        55.10       3.797  131.108333         5.217
# 6290     44             0        52.06       3.781  131.149968         5.217
# 6291     44             0        46.97       3.755  131.193097         5.217
#
#       week  month  year
# 286     17      5  2010
# 287     48     12  2010
# 288      7      2  2010
# 289      8      2  2010
# 290     18      5  2010
# ...    ...    ...   ...
# 6287    39      9  2012
# 6288    19      5  2012
# 6289    50     12  2012
# 6290    42     10  2012
# 6291    43     10  2012
#
# [1840 rows x 9 columns]

# %%
y = df.loc[:,["Weekly_Sales"]]
y
# Out:
#       Weekly_Sales
# 286      461622.22
# 287      420728.96
# 288      421642.19
# 289      407204.86
# 290      415202.04
# ...            ...
# 6287     355307.94
# 6288     337390.44
# 6289     337796.13
# 6290     323766.77
# 6291     361067.07
#
# [1840 rows x 1 columns]

# %% [markdown]
# Splitting the data into train and test

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train
# Out:
#       Store  Holiday_Flag  Temperature  Fuel_Price         CPI  Unemployment  \
# 5942     42             0        85.61       3.794  129.201581         8.257
# 4086     29             0        69.16       3.784  136.244097         9.863
# 4168     30             0        82.29       2.669  210.880373         8.099
# 874       7             0        54.24       2.737  189.445243         8.963
# 4592     33             0        78.47       3.058  126.160226         9.849
# ...     ...           ...          ...         ...         ...           ...
# 4083     29             0        74.69       3.880  136.144129         9.863
# 5040     36             0        66.34       2.595  210.514440         8.476
# 6050     43             0        52.52       2.843  203.447579        10.210
# 2080     15             0        73.63       4.020  136.054032         7.806
# 2224     16             0        67.09       3.542  194.110502         6.338
#
#       week  month  year
# 5942    49     12  2011
# 4086     6      2  2011
# 4168     5      2  2010
# 874     21      5  2010
# 4592    21      5  2010
# ...    ...    ...   ...
# 4083    49     12  2011
# 5040    32      8  2010
# 6050    41     10  2010
# 2080    18      5  2011
# 2224    49     12  2011
#
# [1472 rows x 9 columns]

# %%
y_train
# Out:
#       Weekly_Sales
# 5942     603147.26
# 4086     497085.91
# 4168     450337.47
# 874      442734.55
# 4592     279246.33
# ...            ...
# 4083     471311.50
# 5040     444351.61
# 6050     598679.02
# 2080     607961.21
# 2224     563884.47
#
# [1472 rows x 1 columns]

# %% [markdown]
# Creating the LinearRegression model

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error,r2_score

# %%
linearRegressionError=mean_squared_error(y_test,y_pred)
linearRegressionError
# Out:
# 10356768857.646679

# %%
r2_score(y_test,y_pred)*100
# Out:
# 7.523334951381166

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
r2_score=[]

# %%
y_test.shape[0]
# Out:
# 368

# %%
 rfr=RandomForestRegressor(max_depth=14, random_state=42)

# %%
rfr.fit(x_train,y_train)
# Out:
# RandomForestRegressor(max_depth=14, random_state=42)

# %%
y_pred=rfr.predict(x_test)

# %%
print("mean square error is ",mean_squared_error(y_test,y_pred))
# Out:
# mean square error is  994787505.8400131

# %%
y_test.shape
# Out:
# (368, 1)

# %%
r2_score(y_test,y_pred)*100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [104], in <cell line: 1>()
# ----> 1 r2_score(y_test,y_pred)*100
#
# TypeError: 'list' object is not callable

# %%
x_train.shape

# %%
y_train
# Out:
#       Weekly_Sales
# 5942     603147.26
# 4086     497085.91
# 4168     450337.47
# 874      442734.55
# 4592     279246.33
# ...            ...
# 4083     471311.50
# 5040     444351.61
# 6050     598679.02
# 2080     607961.21
# 2224     563884.47
#
# [1472 rows x 1 columns]

# %%
y_train=y_train.values.reshape(y_train.shape[0],1)

# %%
importance_df = pd.DataFrame({
    'feature': x_train.columns,
    'importance': rfr.feature_importances_
}).sort_values('importance', ascending=False)

plt.figure(figsize=(16,10))
plt.title('Feature Importance')
sns.barplot(data=importance_df, x='importance', y='feature');

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dtr=DecisionTreeRegressor()

# %%
dtr.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred=dtr.predict(x_test)

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 1697427282.5422058

# %%
importance_df = pd.DataFrame({
    'feature': x_train.columns,
    'importance': dtr.feature_importances_
}).sort_values('importance', ascending=False)

plt.figure(figsize=(16,10))
plt.title('Feature Importance')
sns.barplot(data=importance_df, x='importance', y='feature');
